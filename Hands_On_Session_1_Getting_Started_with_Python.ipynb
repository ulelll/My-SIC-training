# %% [markdown]
# <a href="https://colab.research.google.com/github/ulelll/My-SIC-training/blob/first-assigments/Hands_On_Session_1_Getting_Started_with_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello")
# Out:
# Hello

# %% [markdown]
# ini catatan

# %% [markdown]
# # 🐍 Hands-On Session 1: Getting Started with Python
#
# ### 🎯 Session Goal
# Welcome to your first hands-on Python session! By the end of today, you'll understand what makes Python special, why it's the go-to language for AI/ML/IoT, and you'll write your first lines of real Python code.
#
# ### 👋 Welcome
# This notebook is designed to be used **live in class** — we'll code together, run cells, and experiment. Don't worry about memorizing everything; the goal is to get comfortable *running* Python and seeing immediate results. At the end, you'll find a **Homework** section to practice on your own.
#
# **What you'll practice today:**
# - Understanding how Python differs from traditional programming languages
# - Seeing why Python is popular for AI/ML/IoT
# - Using Google Colab basics (running cells, adding cells)
# - Writing correct Python syntax, indentation, and `print()` statements
# - Writing clean, readable code with comments
# - Completing guided practice + take-home homework

# %% [markdown]
# ## 1️⃣ Python vs Traditional Programming
#
# Think of traditional compiled languages (like C or Java) as **writing a full letter, sealing the envelope, and mailing it** — you only find out if there's a mistake after it's sent and opened (compiled and run).
#
# Python is more like **having a live conversation** — you say something (write a line of code), and you get a response immediately. This is because Python is an **interpreted language**: it runs your code line-by-line, instantly.
#
# Let's see this "instant feedback" in action below. 👇

# %%
# Python evaluates and shows results immediately - no separate "compile" step needed
5 * 8 + 2
# Out:
# 42

# %% [markdown]
# ## 2️⃣ Why Python for AI/ML/IoT? 🤖
#
# Python has become the **#1 language** for Artificial Intelligence, Machine Learning, and IoT (Internet of Things). Here's why:
#
# - 📚 **Huge ecosystem of libraries** — NumPy, Pandas, TensorFlow, PyTorch, scikit-learn
# - 🧩 **Simple, readable syntax** — looks almost like English, so you focus on *logic*, not *syntax*
# - 🌍 **Massive community** — millions of tutorials, forums, and ready-made solutions
# - 🔌 **Great for hardware/IoT** — works smoothly with Raspberry Pi, microcontrollers, and sensors
# - ⚡ **Fast to prototype** — go from idea to working demo in minutes
#
# **A simple visual map:**
#
# ```
#         🐍 Python
#        /    |     \
#       /     |      \
#   🤖 AI   📊 Data   🔌 IoT
#   /ML     Science   Devices
#    |         |          |
# TensorFlow Pandas   Raspberry Pi
# PyTorch    NumPy    MicroPython
# ```
#
# Python acts as the **common language** connecting all these exciting fields! 🚀

# %% [markdown]
# ## 3️⃣ Setting Up / Using Google Colab ☁️
#
# We'll be coding in **Google Colab** — a free, browser-based notebook environment. No installation needed!
#
# **Quick tips to get started:**
# - ▶️ **Run a cell**: Click on a cell and press `Shift + Enter` (runs the cell and moves to the next one)
# - ➕ **Add a new cell**: Hover below a cell and click `+ Code` or `+ Text`, or use the `+` icon in the toolbar
# - 🔁 **Re-run a cell**: Just press `Shift + Enter` again after editing
# - 🗑️ **Delete a cell**: Click the trash icon in the top-right of the cell when selected
# - 💾 **Save your work**: `Ctrl + S` (or `Cmd + S` on Mac) — Colab also auto-saves to Google Drive
# - 🆘 **Stuck/frozen cell?**: Use `Runtime > Restart Runtime` to start fresh
#
# Try it now: click into the next code cell and press **Shift + Enter**!

# %% [markdown]
# ## 4️⃣ Syntax, Indentation, and `print()` 🖨️
#
# Python has a few golden rules:
#
# 1. **`print()`** displays output to the screen — it's how Python "talks back" to you.
# 2. **Indentation matters!** Unlike many languages that use `{ }` to group code, Python uses **whitespace (indentation)** to define blocks of code (like inside an `if` statement or a loop). Incorrect indentation will cause an error.
# 3. Statements are usually written **one per line**, and don't need semicolons.
#
# Let's practice step by step. 👇

# %%
# A basic print statement
print("Hello, Python!")
# Out:
# Hello, Python!

# %%
print("Hello, Fajri")
# Out:
# Hello, Fajri

# %%
# print() can take multiple arguments, separated by commas
# Python automatically adds a space between them
print("My name is", "Alex", "and I am learning Python!")
# Out:
# My name is Alex and I am learning Python!

# %% [markdown]
# ### ⚠️ What NOT To Do: Broken Indentation
#
# Below is an example of **incorrect indentation** (shown as text, not run, so it doesn't break our notebook). In Python, this would raise an `IndentationError`:
#
# ```python
# if 5 > 2:
# print("Five is greater than two")   # ❌ Error! This line needs to be indented
# ```
#
# Python expects the code **inside** the `if` block to be indented consistently (usually 4 spaces). Let's see the **correct** version in the next cell. ✅

# %%
# Correct indentation - the line inside the "if" block is indented with 4 spaces
if 5 > 2:
  print("Five is greater than two")  # ✅ This works!
# Out:
# Five is greater than two

# %% [markdown]
# ## 5️⃣ Comments & Code Readability 💬
#
# Comments start with `#` and are ignored by Python when the code runs. They're notes **for humans**, not the computer. Good comments explain *why* something is done, not just *what* (the code already shows *what*).

# %%
# ❌ BAD comment: just repeats what the code obviously does
x = 5  # set x to 5

# ✅ GOOD comment: explains the purpose/reasoning
x = 5  # number of students in the study group, used later to split tasks evenly

print(x)
# Out:
# 5

# %% [markdown]
# ## 🧑‍💻 In-Class Practice (Guided)
#
# Let's practice together! Fill in the blanks below (`# TODO`) and run each cell with `Shift + Enter`.

# %%
# TODO: Print your own name using print()
# Example: print("My name is ___")

print("My name is Fajri")
# Out:
# My name is Fajri

# %%
# TODO: Use print() to display the result of a simple math operation (e.g., 12 + 8)

print("12 + 8 = ", 12 + 8)
# Out:
# 12 + 8 =  20

# %%
# TODO: Write an if statement that checks if 10 > 3, and print a message if it's true
# Remember: don't forget the indentation!

if 10 > 3:
  print("It`s true")
# Out:
# It`s true

# %%
type(3)
# Out:
# int

# %% [markdown]
# ---
# ## 🏠 Homework — Try This At Home
#
# Great job today! 🎉 Now it's time to practice on your own. Complete the exercises below **before the next session**. Take your time, and don't worry about mistakes — that's how you learn!

# %% [markdown]
# ### 📝 Exercise 1 (Easy): Print a Short Bio
# Using **multiple `print()` statements**, print a short bio about yourself: your name, your hobby, and one thing you hope to learn in this course.

# %%
# Write your bio here using multiple print() statements

class Hobby:
    def __init__(self, hobi): 
        self.hobi = hobi

name = "Aurell FM"
hobbies = [
    Hobby("collecting dicast"),
    Hobby("Watch Motorsports"),
    Hobby("gaming")
]

hope = "i wanna recall my python knowlegde after not learning it for years"

print(f"Hello, My name is {name}")
print(f"my hobies are {', '.join(h.hobi for h in hobbies)}")
print(f"and my hope on what to learn in this course {hope}")
# Out:
# Hello, My name is Aurell FM
# my hobies are collecting dicast, Watch Motorsports, gaming
# and my hope on what to learn in this course i wanna recall my python knowlegde after not learning it for years

# %% [markdown]
# ### 📝 Exercise 2 (Easy-Medium): Fix the Broken Indentation
# The snippet below has broken indentation (don't run it as-is — first fix it in the empty cell underneath).
#
# ```python
# if 7 > 4:
# print("Seven is greater than four")
# ```
#
# Copy the corrected version into the code cell below and run it.

# %%
# Fix the indentation error from the snippet above and run it here
if 7 > 4: 
    print("sven is greater than four")
# Out:
# sven is greater than four

# %% [markdown]
# ### 📝 Exercise 3 (Medium): Comment Your Code
# Write ONE line of Python code (any simple operation, like a calculation or a print statement) and add a comment above or beside it explaining **why** someone might use that line.

# %%
# Write your code line here, with a meaningful comment explaining it
print("haaaaayyyy") #its a print of my greeting
# Out:
# haaaaayyyy

# %% [markdown]
# ### 📝 Exercise 4 (Medium-Hard): Math with print()
# Use `print()` to display the result of a math expression involving **at least 3 numbers and 2 different operators** (e.g., multiplication and subtraction).

# %%
# Write a print() statement showing a math expression with 3+ numbers and 2+ operators
x = int(input("masukkan angka ke-1: "))
y = int(input("masukkan angka ke-2: "))
z = int(input("masukkan angka ke-3: "))

hasiltambah = x + y + z
hasilkurang = x - y - z 

print(f"hasil = {hasiltambah}")
print(f"hasil = {hasilkurang}")
# Out:
# hasil = 9
# hasil = -5

# %% [markdown]
# ### 📝 Exercise 5 (Hard): Multiple Conditions (Optional)
# Write an `if` statement that checks if a number (you choose the value) is greater than 10 **and** less than 100, then prints a message if true. Pay close attention to indentation!

# %%
# Write your if statement here

angka  = int(input("masukkan angka kamu: "))

if angka > 10 and angka < 100: 
    print("True")
else: 
    print("false")
# Out:
# false

# %% [markdown]
# ### 🌟 Bonus Challenge (Optional)
# Combine what you've learned! Write a small snippet that:
# 1. Stores your age in a variable
# 2. Uses an `if` statement to check if you are old enough to vote (18+) in your country
# 3. Prints a personalized message using `print()` with multiple arguments
#
# This is optional but a great way to push yourself further. 💪

# %%
# Bonus challenge - combine variables, if statements, and print()
umur = int(input("masukkan umur kamu: "))

class Access:
    def __init__(self, akses):
        self.akses = akses

accesses = [
    Access("ikut pemilu"), 
    Access("main roblox"), 
    Access("buat KTP"), 
    Access("kata prabowo boleh pacaran")
]

if umur > 18: 
    print(f"Kamu bisa melakukan ini: {', '.join(h.akses for h in accesses)}")
else: 
    print("nO access!")
# Out:
# Kamu bisa melakukan ini: ikut pemilu, main roblox, buat KTP, kata prabowo boleh pacaran

# %% [markdown]
# ---
# ### ✅ Recap
# Today you learned:
# - How Python's interactive style differs from traditional programming
# - Why Python is the top choice for AI/ML/IoT
# - Google Colab basics
# - `print()`, syntax, and indentation rules
# - Writing helpful comments
#
# See you in the next session! 🚀
